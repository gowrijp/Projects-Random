# %%
import tensorflow as tf
import tarfile
import urllib
import os
import numpy as np
import pets

from matplotlib import pyplot as plt
# %matplotlib inline

data_dir = 'data/'
if not os.path.isdir(data_dir):
    os.mkdir(data_dir)

print('TensorFlow version:', tf.__version__)
print('Is using GPU?', tf.test.is_gpu_available())
# Out:
# TensorFlow version: 1.15.0
# Is using GPU? False

# %%
pets.download_and_extract('data', '.')
# Out:
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %%
class_to_index = {'cat': 0, 'dog': 1}
index_to_class = {0: 'cat', 1: 'dog'}

train_annot, count_train = pets.cats_vs_dogs_annotations('data/annotations/trainval.txt')
test_annot, count_test = pets.cats_vs_dogs_annotations('data/annotations/test.txt')

print('Training examples count:', count_train)
print('Test examples count:', count_test)
# Out:
# Training examples count: 3680
# Test examples count: 3669

# %%
test_annot
# Out:
# {'Abyssinian_201.jpg': 'cat',
#  'Abyssinian_202.jpg': 'cat',
#  'Abyssinian_204.jpg': 'cat',
#  'Abyssinian_205.jpg': 'cat',
#  'Abyssinian_206.jpg': 'cat',
#  'Abyssinian_207.jpg': 'cat',
#  'Abyssinian_20.jpg': 'cat',
#  'Abyssinian_210.jpg': 'cat',
#  'Abyssinian_212.jpg': 'cat',
#  'Abyssinian_213.jpg': 'cat',
#  'Abyssinian_215.jpg': 'cat',
#  'Abyssinian_216.jpg': 'cat',
#  'Abyssinian_217.jpg': 'cat',
#  'Abyssinian_219.jpg': 'cat',
#  'Abyssinian_21.jpg': 'cat',
#  'Abyssinian_220.jpg': 'cat',
#  'Abyssinian_221.jpg': 'cat',
#  'Abyssinian_223.jpg': 'cat',
#  'Abyssinian_224.jpg': 'cat',
#  'Abyssinian_225.jpg': 'cat',
#  'Abyssinian_226.jpg': 'cat',
#  'Abyssinian_228.jpg': 'cat',
#  'Abyssinian_22.jpg': 'cat',
#  'Abyssinian_230.jpg': 'cat',
#  'Abyssinian_232.jpg': 'cat',
#  'Abyssinian_24.jpg': 'cat',
#  'Abyssinian_25.jpg': 'cat',
#  'Abyssinian_26.jpg': 'cat',
#  'Abyssinian_27.jpg': 'cat',
#  'Abyssinian_29.jpg': 'cat',
#  'Abyssinian_2.jpg': 'cat',
#  'Abyssinian_30.jpg': 'cat',
#  'Abyssinian_31.jpg': 'cat',
#  'Abyssinian_32.jpg': 'cat',
#  'Abyssinian_33.jpg': 'cat',
#  'Abyssinian_36.jpg': 'cat',
#  'Abyssinian_37.jpg': 'cat',
#  'Abyssinian_3.jpg': 'cat',
#  'Abyssinian_40.jpg': 'cat',
#  'Abyssinian_43.jpg': 'cat',
#  'Abyssinian_44.jpg': 'cat',
#  'Abyssinian_45.jpg': 'cat',
#  'Abyssinian_46.jpg': 'cat',
#  'Abyssinian_47.jpg': 'cat',
#  'Abyssinian_48.jpg': 'cat',
#  'Abyssinian_49.jpg': 'cat',
#  'Abyssinian_4.jpg': 'cat',
#  'Abyssinian_50.jpg': 'cat',
#  'Abyssinian_51.jpg': 'cat',
#  'Abyssinian_52.jpg': 'cat',
#  'Abyssinian_54.jpg': 'cat',
#  'Abyssinian_55.jpg': 'cat',
#  'Abyssinian_56.jpg': 'cat',
#  'Abyssinian_57.jpg': 'cat',
#  'Abyssinian_58.jpg': 'cat',
#  'Abyssinian_5.jpg': 'cat',
#  'Abyssinian_60.jpg': 'cat',
#  'Abyssinian_61.jpg': 'cat',
#  'Abyssinian_62.jpg': 'cat',
#  'Abyssinian_63.jpg': 'cat',
#  'Abyssinian_65.jpg': 'cat',
#  'Abyssinian_66.jpg': 'cat',
#  'Abyssinian_67.jpg': 'cat',
#  'Abyssinian_68.jpg': 'cat',
#  'Abyssinian_69.jpg': 'cat',
#  'Abyssinian_6.jpg': 'cat',
#  'Abyssinian_70.jpg': 'cat',
#  'Abyssinian_71.jpg': 'cat',
#  'Abyssinian_72.jpg': 'cat',
#  'Abyssinian_73.jpg': 'cat',
#  'Abyssinian_74.jpg': 'cat',
#  'Abyssinian_75.jpg': 'cat',
#  'Abyssinian_76.jpg': 'cat',
#  'Abyssinian_77.jpg': 'cat',
#  'Abyssinian_78.jpg': 'cat',
#  'Abyssinian_79.jpg': 'cat',
#  'Abyssinian_7.jpg': 'cat',
#  'Abyssinian_80.jpg': 'cat',
#  'Abyssinian_81.jpg': 'cat',
#  'Abyssinian_83.jpg': 'cat',
#  'Abyssinian_84.jpg': 'cat',
#  'Abyssinian_85.jpg': 'cat',
#  'Abyssinian_86.jpg': 'cat',
#  'Abyssinian_87.jpg': 'cat',
#  'Abyssinian_88.jpg': 'cat',
#  'Abyssinian_89.jpg': 'cat',
#  'Abyssinian_8.jpg': 'cat',
#  'Abyssinian_90.jpg': 'cat',
#  'Abyssinian_91.jpg': 'cat',
#  'Abyssinian_92.jpg': 'cat',
#  'Abyssinian_93.jpg': 'cat',
#  'Abyssinian_94.jpg': 'cat',
#  'Abyssinian_95.jpg': 'cat',
#  'Abyssinian_96.jpg': 'cat',
#  'Abyssinian_97.jpg': 'cat',
#  'Abyssinian_98.jpg': 'cat',
#  'Abyssinian_99.jpg': 'cat',
#  'Abyssinian_9.jpg': 'cat',
#  'american_bulldog_203.jpg': 'dog',
#  'american_bulldog_205.jpg': 'dog',
#  'american_bulldog_207.jpg': 'dog',
#  'american_bulldog_208.jpg': 'dog',
#  'american_bulldog_209.jpg': 'dog',
#  'american_bulldog_20.jpg': 'dog',
#  'american_bulldog_211.jpg': 'dog',
#  'american_bulldog_212.jpg': 'dog',
#  'american_bulldog_214.jpg': 'dog',
#  'american_bulldog_216.jpg': 'dog',
#  'american_bulldog_217.jpg': 'dog',
#  'american_bulldog_218.jpg': 'dog',
#  'american_bulldog_21.jpg': 'dog',
#  'american_bulldog_220.jpg': 'dog',
#  'american_bulldog_221.jpg': 'dog',
#  'american_bulldog_224.jpg': 'dog',
#  'american_bulldog_22.jpg': 'dog',
#  'american_bulldog_23.jpg': 'dog',
#  'american_bulldog_24.jpg': 'dog',
#  'american_bulldog_25.jpg': 'dog',
#  'american_bulldog_26.jpg': 'dog',
#  'american_bulldog_27.jpg': 'dog',
#  'american_bulldog_28.jpg': 'dog',
#  'american_bulldog_29.jpg': 'dog',
#  'american_bulldog_2.jpg': 'dog',
#  'american_bulldog_30.jpg': 'dog',
#  'american_bulldog_31.jpg': 'dog',
#  'american_bulldog_32.jpg': 'dog',
#  'american_bulldog_33.jpg': 'dog',
#  'american_bulldog_34.jpg': 'dog',
#  'american_bulldog_35.jpg': 'dog',
#  'american_bulldog_36.jpg': 'dog',
#  'american_bulldog_37.jpg': 'dog',
#  'american_bulldog_38.jpg': 'dog',
#  'american_bulldog_39.jpg': 'dog',
#  'american_bulldog_3.jpg': 'dog',
#  'american_bulldog_40.jpg': 'dog',
#  'american_bulldog_41.jpg': 'dog',
#  'american_bulldog_42.jpg': 'dog',
#  'american_bulldog_43.jpg': 'dog',
#  'american_bulldog_44.jpg': 'dog',
#  'american_bulldog_45.jpg': 'dog',
#  'american_bulldog_46.jpg': 'dog',
#  'american_bulldog_47.jpg': 'dog',
#  'american_bulldog_48.jpg': 'dog',
#  'american_bulldog_49.jpg': 'dog',
#  'american_bulldog_50.jpg': 'dog',
#  'american_bulldog_51.jpg': 'dog',
#  'american_bulldog_52.jpg': 'dog',
#  'american_bulldog_53.jpg': 'dog',
#  'american_bulldog_54.jpg': 'dog',
#  'american_bulldog_55.jpg': 'dog',
#  'american_bulldog_56.jpg': 'dog',
#  'american_bulldog_57.jpg': 'dog',
#  'american_bulldog_58.jpg': 'dog',
#  'american_bulldog_59.jpg': 'dog',
#  'american_bulldog_5.jpg': 'dog',
#  'american_bulldog_60.jpg': 'dog',
#  'american_bulldog_61.jpg': 'dog',
#  'american_bulldog_62.jpg': 'dog',
#  'american_bulldog_63.jpg': 'dog',
#  'american_bulldog_64.jpg': 'dog',
#  'american_bulldog_65.jpg': 'dog',
#  'american_bulldog_66.jpg': 'dog',
#  'american_bulldog_67.jpg': 'dog',
#  'american_bulldog_68.jpg': 'dog',
#  'american_bulldog_69.jpg': 'dog',
#  'american_bulldog_6.jpg': 'dog',
#  'american_bulldog_70.jpg': 'dog',
#  'american_bulldog_71.jpg': 'dog',
#  'american_bulldog_72.jpg': 'dog',
#  'american_bulldog_73.jpg': 'dog',
#  'american_bulldog_74.jpg': 'dog',
#  'american_bulldog_75.jpg': 'dog',
#  'american_bulldog_76.jpg': 'dog',
#  'american_bulldog_77.jpg': 'dog',
#  'american_bulldog_78.jpg': 'dog',
#  'american_bulldog_79.jpg': 'dog',
#  'american_bulldog_7.jpg': 'dog',
#  'american_bulldog_80.jpg': 'dog',
#  'american_bulldog_81.jpg': 'dog',
#  'american_bulldog_82.jpg': 'dog',
#  'american_bulldog_83.jpg': 'dog',
#  'american_bulldog_84.jpg': 'dog',
#  'american_bulldog_85.jpg': 'dog',
#  'american_bulldog_86.jpg': 'dog',
#  'american_bulldog_87.jpg': 'dog',
#  'american_bulldog_89.jpg': 'dog',
#  'american_bulldog_8.jpg': 'dog',
#  'american_bulldog_90.jpg': 'dog',
#  'american_bulldog_91.jpg': 'dog',
#  'american_bulldog_92.jpg': 'dog',
#  'american_bulldog_93.jpg': 'dog',
#  'american_bulldog_94.jpg': 'dog',
#  'american_bulldog_95.jpg': 'dog',
#  'american_bulldog_96.jpg': 'dog',
#  'american_bulldog_97.jpg': 'dog',
#  'american_bulldog_98.jpg': 'dog',
#  'american_bulldog_99.jpg': 'dog',
#  'american_bulldog_9.jpg': 'dog',
#  'american_pit_bull_terrier_191.jpg': 'dog',
#  'american_pit_bull_terrier_192.jpg': 'dog',
#  'american_pit_bull_terrier_193.jpg': 'dog',
#  'american_pit_bull_terrier_194.jpg': 'dog',
#  'american_pit_bull_terrier_195.jpg': 'dog',
#  'american_pit_bull_terrier_196.jpg': 'dog',
#  'american_pit_bull_terrier_197.jpg': 'dog',
#  'american_pit_bull_terrier_198.jpg': 'dog',
#  'american_pit_bull_terrier_199.jpg': 'dog',
#  'american_pit_bull_terrier_19.jpg': 'dog',
#  'american_pit_bull_terrier_1.jpg': 'dog',
#  'american_pit_bull_terrier_200.jpg': 'dog',
#  'american_pit_bull_terrier_201.jpg': 'dog',
#  'american_pit_bull_terrier_202.jpg': 'dog',
#  'american_pit_bull_terrier_203.jpg': 'dog',
#  'american_pit_bull_terrier_204.jpg': 'dog',
#  'american_pit_bull_terrier_20.jpg': 'dog',
#  'american_pit_bull_terrier_21.jpg': 'dog',
#  'american_pit_bull_terrier_22.jpg': 'dog',
#  'american_pit_bull_terrier_23.jpg': 'dog',
#  'american_pit_bull_terrier_24.jpg': 'dog',
#  'american_pit_bull_terrier_25.jpg': 'dog',
#  'american_pit_bull_terrier_26.jpg': 'dog',
#  'american_pit_bull_terrier_27.jpg': 'dog',
#  'american_pit_bull_terrier_28.jpg': 'dog',
#  'american_pit_bull_terrier_29.jpg': 'dog',
#  'american_pit_bull_terrier_2.jpg': 'dog',
#  'american_pit_bull_terrier_30.jpg': 'dog',
#  'american_pit_bull_terrier_31.jpg': 'dog',
#  'american_pit_bull_terrier_32.jpg': 'dog',
#  'american_pit_bull_terrier_33.jpg': 'dog',
#  'american_pit_bull_terrier_35.jpg': 'dog',
#  'american_pit_bull_terrier_36.jpg': 'dog',
#  'american_pit_bull_terrier_37.jpg': 'dog',
#  'american_pit_bull_terrier_38.jpg': 'dog',
#  'american_pit_bull_terrier_39.jpg': 'dog',
#  'american_pit_bull_terrier_40.jpg': 'dog',
#  'american_pit_bull_terrier_41.jpg': 'dog',
#  'american_pit_bull_terrier_42.jpg': 'dog',
#  'american_pit_bull_terrier_43.jpg': 'dog',
#  'american_pit_bull_terrier_44.jpg': 'dog',
#  'american_pit_bull_terrier_45.jpg': 'dog',
#  'american_pit_bull_terrier_46.jpg': 'dog',
#  'american_pit_bull_terrier_47.jpg': 'dog',
#  'american_pit_bull_terrier_48.jpg': 'dog',
#  'american_pit_bull_terrier_49.jpg': 'dog',
#  'american_pit_bull_terrier_4.jpg': 'dog',
#  'american_pit_bull_terrier_50.jpg': 'dog',
#  'american_pit_bull_terrier_51.jpg': 'dog',
#  'american_pit_bull_terrier_52.jpg': 'dog',
#  'american_pit_bull_terrier_53.jpg': 'dog',
#  'american_pit_bull_terrier_54.jpg': 'dog',
#  'american_pit_bull_terrier_55.jpg': 'dog',
#  'american_pit_bull_terrier_56.jpg': 'dog',
#  'american_pit_bull_terrier_57.jpg': 'dog',
#  'american_pit_bull_terrier_58.jpg': 'dog',
#  'american_pit_bull_terrier_59.jpg': 'dog',
#  'american_pit_bull_terrier_5.jpg': 'dog',
#  'american_pit_bull_terrier_60.jpg': 'dog',
#  'american_pit_bull_terrier_61.jpg': 'dog',
#  'american_pit_bull_terrier_62.jpg': 'dog',
#  'american_pit_bull_terrier_63.jpg': 'dog',
#  'american_pit_bull_terrier_64.jpg': 'dog',
#  'american_pit_bull_terrier_65.jpg': 'dog',
#  'american_pit_bull_terrier_66.jpg': 'dog',
#  'american_pit_bull_terrier_67.jpg': 'dog',
#  'american_pit_bull_terrier_68.jpg': 'dog',
#  'american_pit_bull_terrier_69.jpg': 'dog',
#  'american_pit_bull_terrier_6.jpg': 'dog',
#  'american_pit_bull_terrier_70.jpg': 'dog',
#  'american_pit_bull_terrier_71.jpg': 'dog',
#  'american_pit_bull_terrier_72.jpg': 'dog',
#  'american_pit_bull_terrier_73.jpg': 'dog',
#  'american_pit_bull_terrier_74.jpg': 'dog',
#  'american_pit_bull_terrier_75.jpg': 'dog',
#  'american_pit_bull_terrier_76.jpg': 'dog',
#  'american_pit_bull_terrier_77.jpg': 'dog',
#  'american_pit_bull_terrier_78.jpg': 'dog',
#  'american_pit_bull_terrier_79.jpg': 'dog',
#  'american_pit_bull_terrier_7.jpg': 'dog',
#  'american_pit_bull_terrier_80.jpg': 'dog',
#  'american_pit_bull_terrier_81.jpg': 'dog',
#  'american_pit_bull_terrier_82.jpg': 'dog',
#  'american_pit_bull_terrier_84.jpg': 'dog',
#  'american_pit_bull_terrier_86.jpg': 'dog',
#  'american_pit_bull_terrier_87.jpg': 'dog',
#  'american_pit_bull_terrier_88.jpg': 'dog',
#  'american_pit_bull_terrier_89.jpg': 'dog',
#  'american_pit_bull_terrier_8.jpg': 'dog',
#  'american_pit_bull_terrier_90.jpg': 'dog',
#  'american_pit_bull_terrier_91.jpg': 'dog',
#  'american_pit_bull_terrier_92.jpg': 'dog',
#  'american_pit_bull_terrier_93.jpg': 'dog',
#  'american_pit_bull_terrier_94.jpg': 'dog',
#  'american_pit_bull_terrier_95.jpg': 'dog',
#  'american_pit_bull_terrier_96.jpg': 'dog',
#  'american_pit_bull_terrier_97.jpg': 'dog',
#  'american_pit_bull_terrier_98.jpg': 'dog',
#  'american_pit_bull_terrier_99.jpg': 'dog',
#  'american_pit_bull_terrier_9.jpg': 'dog',
#  'basset_hound_191.jpg': 'dog',
#  'basset_hound_192.jpg': 'dog',
#  'basset_hound_193.jpg': 'dog',
#  'basset_hound_194.jpg': 'dog',
#  'basset_hound_195.jpg': 'dog',
#  'basset_hound_196.jpg': 'dog',
#  'basset_hound_197.jpg': 'dog',
#  'basset_hound_198.jpg': 'dog',
#  'basset_hound_199.jpg': 'dog',
#  'basset_hound_19.jpg': 'dog',
#  'basset_hound_1.jpg': 'dog',
#  'basset_hound_200.jpg': 'dog',
#  'basset_hound_20.jpg': 'dog',
#  'basset_hound_21.jpg': 'dog',
#  'basset_hound_22.jpg': 'dog',
#  'basset_hound_23.jpg': 'dog',
#  'basset_hound_24.jpg': 'dog',
#  'basset_hound_25.jpg': 'dog',
#  'basset_hound_26.jpg': 'dog',
#  'basset_hound_27.jpg': 'dog',
#  'basset_hound_28.jpg': 'dog',
#  'basset_hound_29.jpg': 'dog',
#  'basset_hound_2.jpg': 'dog',
#  'basset_hound_30.jpg': 'dog',
#  'basset_hound_31.jpg': 'dog',
#  'basset_hound_32.jpg': 'dog',
#  'basset_hound_33.jpg': 'dog',
#  'basset_hound_34.jpg': 'dog',
#  'basset_hound_35.jpg': 'dog',
#  'basset_hound_36.jpg': 'dog',
#  'basset_hound_37.jpg': 'dog',
#  'basset_hound_38.jpg': 'dog',
#  'basset_hound_39.jpg': 'dog',
#  'basset_hound_3.jpg': 'dog',
#  'basset_hound_40.jpg': 'dog',
#  'basset_hound_41.jpg': 'dog',
#  'basset_hound_42.jpg': 'dog',
#  'basset_hound_43.jpg': 'dog',
#  'basset_hound_44.jpg': 'dog',
#  'basset_hound_45.jpg': 'dog',
#  'basset_hound_46.jpg': 'dog',
#  'basset_hound_47.jpg': 'dog',
#  'basset_hound_48.jpg': 'dog',
#  'basset_hound_49.jpg': 'dog',
#  'basset_hound_4.jpg': 'dog',
#  'basset_hound_50.jpg': 'dog',
#  'basset_hound_51.jpg': 'dog',
#  'basset_hound_52.jpg': 'dog',
#  'basset_hound_53.jpg': 'dog',
#  'basset_hound_54.jpg': 'dog',
#  'basset_hound_55.jpg': 'dog',
#  'basset_hound_56.jpg': 'dog',
#  'basset_hound_57.jpg': 'dog',
#  'basset_hound_58.jpg': 'dog',
#  'basset_hound_59.jpg': 'dog',
#  'basset_hound_5.jpg': 'dog',
#  'basset_hound_60.jpg': 'dog',
#  'basset_hound_61.jpg': 'dog',
#  'basset_hound_62.jpg': 'dog',
#  'basset_hound_63.jpg': 'dog',
#  'basset_hound_64.jpg': 'dog',
#  'basset_hound_65.jpg': 'dog',
#  'basset_hound_66.jpg': 'dog',
#  'basset_hound_67.jpg': 'dog',
#  'basset_hound_68.jpg': 'dog',
#  'basset_hound_69.jpg': 'dog',
#  'basset_hound_6.jpg': 'dog',
#  'basset_hound_70.jpg': 'dog',
#  'basset_hound_71.jpg': 'dog',
#  'basset_hound_72.jpg': 'dog',
#  'basset_hound_73.jpg': 'dog',
#  'basset_hound_74.jpg': 'dog',
#  'basset_hound_75.jpg': 'dog',
#  'basset_hound_76.jpg': 'dog',
#  'basset_hound_77.jpg': 'dog',
#  'basset_hound_78.jpg': 'dog',
#  'basset_hound_79.jpg': 'dog',
#  'basset_hound_7.jpg': 'dog',
#  'basset_hound_80.jpg': 'dog',
#  'basset_hound_81.jpg': 'dog',
#  'basset_hound_82.jpg': 'dog',
#  'basset_hound_83.jpg': 'dog',
#  'basset_hound_84.jpg': 'dog',
#  'basset_hound_85.jpg': 'dog',
#  'basset_hound_86.jpg': 'dog',
#  'basset_hound_87.jpg': 'dog',
#  'basset_hound_88.jpg': 'dog',
#  'basset_hound_89.jpg': 'dog',
#  'basset_hound_8.jpg': 'dog',
#  'basset_hound_90.jpg': 'dog',
#  'basset_hound_91.jpg': 'dog',
#  'basset_hound_92.jpg': 'dog',
#  'basset_hound_93.jpg': 'dog',
#  'basset_hound_94.jpg': 'dog',
#  'basset_hound_95.jpg': 'dog',
#  'basset_hound_96.jpg': 'dog',
#  'basset_hound_97.jpg': 'dog',
#  'basset_hound_98.jpg': 'dog',
#  'basset_hound_99.jpg': 'dog',
#  'basset_hound_9.jpg': 'dog',
#  'beagle_195.jpg': 'dog',
#  'beagle_196.jpg': 'dog',
#  'beagle_197.jpg': 'dog',
#  'beagle_198.jpg': 'dog',
#  'beagle_199.jpg': 'dog',
#  'beagle_19.jpg': 'dog',
#  'beagle_1.jpg': 'dog',
#  'beagle_200.jpg': 'dog',
#  'beagle_201.jpg': 'dog',
#  'beagle_202.jpg': 'dog',
#  'beagle_203.jpg': 'dog',
#  'beagle_204.jpg': 'dog',
#  'beagle_20.jpg': 'dog',
#  'beagle_21.jpg': 'dog',
#  'beagle_22.jpg': 'dog',
#  'beagle_23.jpg': 'dog',
#  'beagle_24.jpg': 'dog',
#  'beagle_25.jpg': 'dog',
#  'beagle_26.jpg': 'dog',
#  'beagle_27.jpg': 'dog',
#  'beagle_28.jpg': 'dog',
#  'beagle_29.jpg': 'dog',
#  'beagle_2.jpg': 'dog',
#  'beagle_30.jpg': 'dog',
#  'beagle_31.jpg': 'dog',
#  'beagle_32.jpg': 'dog',
#  'beagle_33.jpg': 'dog',
#  'beagle_34.jpg': 'dog',
#  'beagle_35.jpg': 'dog',
#  'beagle_36.jpg': 'dog',
#  'beagle_37.jpg': 'dog',
#  'beagle_38.jpg': 'dog',
#  'beagle_39.jpg': 'dog',
#  'beagle_3.jpg': 'dog',
#  'beagle_40.jpg': 'dog',
#  'beagle_41.jpg': 'dog',
#  'beagle_42.jpg': 'dog',
#  'beagle_43.jpg': 'dog',
#  'beagle_44.jpg': 'dog',
#  'beagle_45.jpg': 'dog',
#  'beagle_46.jpg': 'dog',
#  'beagle_47.jpg': 'dog',
#  'beagle_48.jpg': 'dog',
#  'beagle_49.jpg': 'dog',
#  'beagle_4.jpg': 'dog',
#  'beagle_50.jpg': 'dog',
#  'beagle_51.jpg': 'dog',
#  'beagle_52.jpg': 'dog',
#  'beagle_53.jpg': 'dog',
#  'beagle_54.jpg': 'dog',
#  'beagle_55.jpg': 'dog',
#  'beagle_56.jpg': 'dog',
#  'beagle_57.jpg': 'dog',
#  'beagle_58.jpg': 'dog',
#  'beagle_59.jpg': 'dog',
#  'beagle_5.jpg': 'dog',
#  'beagle_60.jpg': 'dog',
#  'beagle_61.jpg': 'dog',
#  'beagle_62.jpg': 'dog',
#  'beagle_63.jpg': 'dog',
#  'beagle_64.jpg': 'dog',
#  'beagle_65.jpg': 'dog',
#  'beagle_66.jpg': 'dog',
#  'beagle_67.jpg': 'dog',
#  'beagle_68.jpg': 'dog',
#  'beagle_69.jpg': 'dog',
#  'beagle_6.jpg': 'dog',
#  'beagle_70.jpg': 'dog',
#  'beagle_71.jpg': 'dog',
#  'beagle_72.jpg': 'dog',
#  'beagle_73.jpg': 'dog',
#  'beagle_74.jpg': 'dog',
#  'beagle_75.jpg': 'dog',
#  'beagle_76.jpg': 'dog',
#  'beagle_77.jpg': 'dog',
#  'beagle_78.jpg': 'dog',
#  'beagle_79.jpg': 'dog',
#  'beagle_7.jpg': 'dog',
#  'beagle_80.jpg': 'dog',
#  'beagle_81.jpg': 'dog',
#  'beagle_82.jpg': 'dog',
#  'beagle_83.jpg': 'dog',
#  'beagle_84.jpg': 'dog',
#  'beagle_85.jpg': 'dog',
#  'beagle_86.jpg': 'dog',
#  'beagle_87.jpg': 'dog',
#  'beagle_88.jpg': 'dog',
#  'beagle_89.jpg': 'dog',
#  'beagle_8.jpg': 'dog',
#  'beagle_90.jpg': 'dog',
#  'beagle_91.jpg': 'dog',
#  'beagle_92.jpg': 'dog',
#  'beagle_93.jpg': 'dog',
#  'beagle_94.jpg': 'dog',
#  'beagle_95.jpg': 'dog',
#  'beagle_96.jpg': 'dog',
#  'beagle_97.jpg': 'dog',
#  'beagle_98.jpg': 'dog',
#  'beagle_99.jpg': 'dog',
#  'beagle_9.jpg': 'dog',
#  'Bengal_192.jpg': 'cat',
#  'Bengal_193.jpg': 'cat',
#  'Bengal_194.jpg': 'cat',
#  'Bengal_195.jpg': 'cat',
#  'Bengal_196.jpg': 'cat',
#  'Bengal_197.jpg': 'cat',
#  'Bengal_198.jpg': 'cat',
#  'Bengal_199.jpg': 'cat',
#  'Bengal_19.jpg': 'cat',
#  'Bengal_1.jpg': 'cat',
#  'Bengal_200.jpg': 'cat',
#  'Bengal_201.jpg': 'cat',
#  'Bengal_20.jpg': 'cat',
#  'Bengal_21.jpg': 'cat',
#  'Bengal_22.jpg': 'cat',
#  'Bengal_23.jpg': 'cat',
#  'Bengal_24.jpg': 'cat',
#  'Bengal_25.jpg': 'cat',
#  'Bengal_26.jpg': 'cat',
#  'Bengal_27.jpg': 'cat',
#  'Bengal_28.jpg': 'cat',
#  'Bengal_29.jpg': 'cat',
#  'Bengal_2.jpg': 'cat',
#  'Bengal_30.jpg': 'cat',
#  'Bengal_31.jpg': 'cat',
#  'Bengal_32.jpg': 'cat',
#  'Bengal_33.jpg': 'cat',
#  'Bengal_34.jpg': 'cat',
#  'Bengal_35.jpg': 'cat',
#  'Bengal_36.jpg': 'cat',
#  'Bengal_37.jpg': 'cat',
#  'Bengal_38.jpg': 'cat',
#  'Bengal_39.jpg': 'cat',
#  'Bengal_3.jpg': 'cat',
#  'Bengal_40.jpg': 'cat',
#  'Bengal_41.jpg': 'cat',
#  'Bengal_42.jpg': 'cat',
#  'Bengal_43.jpg': 'cat',
#  'Bengal_44.jpg': 'cat',
#  'Bengal_45.jpg': 'cat',
#  'Bengal_46.jpg': 'cat',
#  'Bengal_47.jpg': 'cat',
#  'Bengal_48.jpg': 'cat',
#  'Bengal_49.jpg': 'cat',
#  'Bengal_4.jpg': 'cat',
#  'Bengal_50.jpg': 'cat',
#  'Bengal_51.jpg': 'cat',
#  'Bengal_52.jpg': 'cat',
#  'Bengal_53.jpg': 'cat',
#  'Bengal_54.jpg': 'cat',
#  'Bengal_55.jpg': 'cat',
#  'Bengal_56.jpg': 'cat',
#  'Bengal_57.jpg': 'cat',
#  'Bengal_58.jpg': 'cat',
#  'Bengal_59.jpg': 'cat',
#  'Bengal_5.jpg': 'cat',
#  'Bengal_60.jpg': 'cat',
#  'Bengal_61.jpg': 'cat',
#  'Bengal_62.jpg': 'cat',
#  'Bengal_63.jpg': 'cat',
#  'Bengal_64.jpg': 'cat',
#  'Bengal_65.jpg': 'cat',
#  'Bengal_66.jpg': 'cat',
#  'Bengal_67.jpg': 'cat',
#  'Bengal_68.jpg': 'cat',
#  'Bengal_69.jpg': 'cat',
#  'Bengal_6.jpg': 'cat',
#  'Bengal_70.jpg': 'cat',
#  'Bengal_71.jpg': 'cat',
#  'Bengal_72.jpg': 'cat',
#  'Bengal_73.jpg': 'cat',
#  'Bengal_74.jpg': 'cat',
#  'Bengal_75.jpg': 'cat',
#  'Bengal_76.jpg': 'cat',
#  'Bengal_77.jpg': 'cat',
#  'Bengal_78.jpg': 'cat',
#  'Bengal_79.jpg': 'cat',
#  'Bengal_7.jpg': 'cat',
#  'Bengal_80.jpg': 'cat',
#  'Bengal_81.jpg': 'cat',
#  'Bengal_82.jpg': 'cat',
#  'Bengal_83.jpg': 'cat',
#  'Bengal_84.jpg': 'cat',
#  'Bengal_85.jpg': 'cat',
#  'Bengal_86.jpg': 'cat',
#  'Bengal_87.jpg': 'cat',
#  'Bengal_88.jpg': 'cat',
#  'Bengal_89.jpg': 'cat',
#  'Bengal_8.jpg': 'cat',
#  'Bengal_90.jpg': 'cat',
#  'Bengal_91.jpg': 'cat',
#  'Bengal_92.jpg': 'cat',
#  'Bengal_93.jpg': 'cat',
#  'Bengal_94.jpg': 'cat',
#  'Bengal_95.jpg': 'cat',
#  'Bengal_96.jpg': 'cat',
#  'Bengal_97.jpg': 'cat',
#  'Bengal_98.jpg': 'cat',
#  'Bengal_99.jpg': 'cat',
#  'Bengal_9.jpg': 'cat',
#  'Birman_191.jpg': 'cat',
#  'Birman_192.jpg': 'cat',
#  'Birman_193.jpg': 'cat',
#  'Birman_194.jpg': 'cat',
#  'Birman_196.jpg': 'cat',
#  'Birman_197.jpg': 'cat',
#  'Birman_198.jpg': 'cat',
#  'Birman_199.jpg': 'cat',
#  'Birman_19.jpg': 'cat',
#  'Birman_1.jpg': 'cat',
#  'Birman_200.jpg': 'cat',
#  'Birman_201.jpg': 'cat',
#  'Birman_20.jpg': 'cat',
#  'Birman_21.jpg': 'cat',
#  'Birman_22.jpg': 'cat',
#  'Birman_23.jpg': 'cat',
#  'Birman_24.jpg': 'cat',
#  'Birman_25.jpg': 'cat',
#  'Birman_26.jpg': 'cat',
#  'Birman_27.jpg': 'cat',
#  'Birman_28.jpg': 'cat',
#  'Birman_29.jpg': 'cat',
#  'Birman_2.jpg': 'cat',
#  'Birman_30.jpg': 'cat',
#  'Birman_31.jpg': 'cat',
#  'Birman_32.jpg': 'cat',
#  'Birman_33.jpg': 'cat',
#  'Birman_34.jpg': 'cat',
#  'Birman_35.jpg': 'cat',
#  'Birman_36.jpg': 'cat',
#  'Birman_37.jpg': 'cat',
#  'Birman_38.jpg': 'cat',
#  'Birman_39.jpg': 'cat',
#  'Birman_3.jpg': 'cat',
#  'Birman_40.jpg': 'cat',
#  'Birman_41.jpg': 'cat',
#  'Birman_42.jpg': 'cat',
#  'Birman_43.jpg': 'cat',
#  'Birman_44.jpg': 'cat',
#  'Birman_45.jpg': 'cat',
#  'Birman_46.jpg': 'cat',
#  'Birman_47.jpg': 'cat',
#  'Birman_48.jpg': 'cat',
#  'Birman_49.jpg': 'cat',
#  'Birman_4.jpg': 'cat',
#  'Birman_50.jpg': 'cat',
#  'Birman_51.jpg': 'cat',
#  'Birman_52.jpg': 'cat',
#  'Birman_53.jpg': 'cat',
#  'Birman_54.jpg': 'cat',
#  'Birman_55.jpg': 'cat',
#  'Birman_56.jpg': 'cat',
#  'Birman_57.jpg': 'cat',
#  'Birman_58.jpg': 'cat',
#  'Birman_59.jpg': 'cat',
#  'Birman_5.jpg': 'cat',
#  'Birman_60.jpg': 'cat',
#  'Birman_61.jpg': 'cat',
#  'Birman_62.jpg': 'cat',
#  'Birman_63.jpg': 'cat',
#  'Birman_64.jpg': 'cat',
#  'Birman_65.jpg': 'cat',
#  'Birman_66.jpg': 'cat',
#  'Birman_67.jpg': 'cat',
#  'Birman_68.jpg': 'cat',
#  'Birman_69.jpg': 'cat',
#  'Birman_6.jpg': 'cat',
#  'Birman_70.jpg': 'cat',
#  'Birman_71.jpg': 'cat',
#  'Birman_72.jpg': 'cat',
#  'Birman_73.jpg': 'cat',
#  'Birman_74.jpg': 'cat',
#  'Birman_75.jpg': 'cat',
#  'Birman_76.jpg': 'cat',
#  'Birman_77.jpg': 'cat',
#  'Birman_78.jpg': 'cat',
#  'Birman_79.jpg': 'cat',
#  'Birman_7.jpg': 'cat',
#  'Birman_80.jpg': 'cat',
#  'Birman_81.jpg': 'cat',
#  'Birman_82.jpg': 'cat',
#  'Birman_83.jpg': 'cat',
#  'Birman_84.jpg': 'cat',
#  'Birman_85.jpg': 'cat',
#  'Birman_86.jpg': 'cat',
#  'Birman_87.jpg': 'cat',
#  'Birman_88.jpg': 'cat',
#  'Birman_89.jpg': 'cat',
#  'Birman_8.jpg': 'cat',
#  'Birman_90.jpg': 'cat',
#  'Birman_91.jpg': 'cat',
#  'Birman_92.jpg': 'cat',
#  'Birman_93.jpg': 'cat',
#  'Birman_94.jpg': 'cat',
#  'Birman_95.jpg': 'cat',
#  'Birman_96.jpg': 'cat',
#  'Birman_97.jpg': 'cat',
#  'Birman_98.jpg': 'cat',
#  'Birman_99.jpg': 'cat',
#  'Birman_9.jpg': 'cat',
#  'Bombay_200.jpg': 'cat',
#  'Bombay_201.jpg': 'cat',
#  'Bombay_202.jpg': 'cat',
#  'Bombay_204.jpg': 'cat',
#  'Bombay_205.jpg': 'cat',
#  'Bombay_208.jpg': 'cat',
#  'Bombay_20.jpg': 'cat',
#  'Bombay_213.jpg': 'cat',
#  'Bombay_214.jpg': 'cat',
#  'Bombay_215.jpg': 'cat',
#  'Bombay_21.jpg': 'cat',
#  'Bombay_221.jpg': 'cat',
#  'Bombay_23.jpg': 'cat',
#  'Bombay_24.jpg': 'cat',
#  'Bombay_25.jpg': 'cat',
#  'Bombay_26.jpg': 'cat',
#  'Bombay_27.jpg': 'cat',
#  'Bombay_29.jpg': 'cat',
#  'Bombay_2.jpg': 'cat',
#  'Bombay_30.jpg': 'cat',
#  'Bombay_31.jpg': 'cat',
#  'Bombay_33.jpg': 'cat',
#  'Bombay_34.jpg': 'cat',
#  'Bombay_36.jpg': 'cat',
#  'Bombay_37.jpg': 'cat',
#  'Bombay_38.jpg': 'cat',
#  'Bombay_39.jpg': 'cat',
#  'Bombay_3.jpg': 'cat',
#  'Bombay_40.jpg': 'cat',
#  'Bombay_41.jpg': 'cat',
#  'Bombay_42.jpg': 'cat',
#  'Bombay_43.jpg': 'cat',
#  'Bombay_45.jpg': 'cat',
#  'Bombay_46.jpg': 'cat',
#  'Bombay_47.jpg': 'cat',
#  'Bombay_48.jpg': 'cat',
#  'Bombay_49.jpg': 'cat',
#  'Bombay_4.jpg': 'cat',
#  'Bombay_50.jpg': 'cat',
#  'Bombay_52.jpg': 'cat',
#  'Bombay_53.jpg': 'cat',
#  'Bombay_54.jpg': 'cat',
#  'Bombay_55.jpg': 'cat',
#  'Bombay_56.jpg': 'cat',
#  'Bombay_57.jpg': 'cat',
#  'Bombay_58.jpg': 'cat',
#  'Bombay_59.jpg': 'cat',
#  'Bombay_5.jpg': 'cat',
#  'Bombay_60.jpg': 'cat',
#  'Bombay_61.jpg': 'cat',
#  'Bombay_62.jpg': 'cat',
#  'Bombay_63.jpg': 'cat',
#  'Bombay_64.jpg': 'cat',
#  'Bombay_65.jpg': 'cat',
#  'Bombay_66.jpg': 'cat',
#  'Bombay_67.jpg': 'cat',
#  'Bombay_68.jpg': 'cat',
#  'Bombay_6.jpg': 'cat',
#  'Bombay_70.jpg': 'cat',
#  'Bombay_71.jpg': 'cat',
#  'Bombay_72.jpg': 'cat',
#  'Bombay_73.jpg': 'cat',
#  'Bombay_74.jpg': 'cat',
#  'Bombay_75.jpg': 'cat',
#  'Bombay_76.jpg': 'cat',
#  'Bombay_77.jpg': 'cat',
#  'Bombay_78.jpg': 'cat',
#  'Bombay_79.jpg': 'cat',
#  'Bombay_7.jpg': 'cat',
#  'Bombay_80.jpg': 'cat',
#  'Bombay_81.jpg': 'cat',
#  'Bombay_82.jpg': 'cat',
#  'Bombay_83.jpg': 'cat',
#  'Bombay_84.jpg': 'cat',
#  'Bombay_86.jpg': 'cat',
#  'Bombay_87.jpg': 'cat',
#  'Bombay_88.jpg': 'cat',
#  'Bombay_89.jpg': 'cat',
#  'Bombay_8.jpg': 'cat',
#  'Bombay_90.jpg': 'cat',
#  'Bombay_91.jpg': 'cat',
#  'Bombay_93.jpg': 'cat',
#  'Bombay_94.jpg': 'cat',
#  'Bombay_95.jpg': 'cat',
#  'Bombay_96.jpg': 'cat',
#  'Bombay_97.jpg': 'cat',
#  'Bombay_98.jpg': 'cat',
#  'Bombay_9.jpg': 'cat',
#  'boxer_191.jpg': 'dog',
#  'boxer_192.jpg': 'dog',
#  'boxer_193.jpg': 'dog',
#  'boxer_194.jpg': 'dog',
#  'boxer_195.jpg': 'dog',
#  'boxer_196.jpg': 'dog',
#  'boxer_197.jpg': 'dog',
#  'boxer_198.jpg': 'dog',
#  'boxer_199.jpg': 'dog',
#  'boxer_19.jpg': 'dog',
#  'boxer_1.jpg': 'dog',
#  'boxer_200.jpg': 'dog',
#  'boxer_20.jpg': 'dog',
#  'boxer_21.jpg': 'dog',
#  'boxer_22.jpg': 'dog',
#  'boxer_23.jpg': 'dog',
#  'boxer_24.jpg': 'dog',
#  'boxer_25.jpg': 'dog',
#  'boxer_26.jpg': 'dog',
#  'boxer_27.jpg': 'dog',
#  'boxer_28.jpg': 'dog',
#  'boxer_29.jpg': 'dog',
#  'boxer_2.jpg': 'dog',
#  'boxer_30.jpg': 'dog',
#  'boxer_31.jpg': 'dog',
#  'boxer_32.jpg': 'dog',
#  'boxer_33.jpg': 'dog',
#  'boxer_34.jpg': 'dog',
#  'boxer_35.jpg': 'dog',
#  'boxer_36.jpg': 'dog',
#  'boxer_37.jpg': 'dog',
#  'boxer_38.jpg': 'dog',
#  'boxer_39.jpg': 'dog',
#  'boxer_3.jpg': 'dog',
#  'boxer_40.jpg': 'dog',
#  'boxer_41.jpg': 'dog',
#  'boxer_42.jpg': 'dog',
#  'boxer_43.jpg': 'dog',
#  'boxer_44.jpg': 'dog',
#  'boxer_45.jpg': 'dog',
#  'boxer_46.jpg': 'dog',
#  'boxer_47.jpg': 'dog',
#  'boxer_48.jpg': 'dog',
#  'boxer_49.jpg': 'dog',
#  'boxer_4.jpg': 'dog',
#  'boxer_50.jpg': 'dog',
#  'boxer_51.jpg': 'dog',
#  'boxer_52.jpg': 'dog',
#  'boxer_53.jpg': 'dog',
#  'boxer_54.jpg': 'dog',
#  'boxer_55.jpg': 'dog',
#  'boxer_56.jpg': 'dog',
#  'boxer_57.jpg': 'dog',
#  'boxer_58.jpg': 'dog',
#  'boxer_59.jpg': 'dog',
#  'boxer_5.jpg': 'dog',
#  'boxer_60.jpg': 'dog',
#  'boxer_61.jpg': 'dog',
#  'boxer_62.jpg': 'dog',
#  'boxer_63.jpg': 'dog',
#  'boxer_64.jpg': 'dog',
#  'boxer_65.jpg': 'dog',
#  'boxer_66.jpg': 'dog',
#  'boxer_67.jpg': 'dog',
#  'boxer_68.jpg': 'dog',
#  'boxer_69.jpg': 'dog',
#  'boxer_6.jpg': 'dog',
#  'boxer_70.jpg': 'dog',
#  'boxer_71.jpg': 'dog',
#  'boxer_72.jpg': 'dog',
#  'boxer_73.jpg': 'dog',
#  'boxer_74.jpg': 'dog',
#  'boxer_75.jpg': 'dog',
#  'boxer_76.jpg': 'dog',
#  'boxer_77.jpg': 'dog',
#  'boxer_78.jpg': 'dog',
#  'boxer_79.jpg': 'dog',
#  'boxer_7.jpg': 'dog',
#  'boxer_80.jpg': 'dog',
#  'boxer_81.jpg': 'dog',
#  'boxer_83.jpg': 'dog',
#  'boxer_84.jpg': 'dog',
#  'boxer_85.jpg': 'dog',
#  'boxer_86.jpg': 'dog',
#  'boxer_87.jpg': 'dog',
#  'boxer_88.jpg': 'dog',
#  'boxer_89.jpg': 'dog',
#  'boxer_8.jpg': 'dog',
#  'boxer_90.jpg': 'dog',
#  'boxer_91.jpg': 'dog',
#  'boxer_92.jpg': 'dog',
#  'boxer_93.jpg': 'dog',
#  'boxer_94.jpg': 'dog',
#  'boxer_95.jpg': 'dog',
#  'boxer_96.jpg': 'dog',
#  'boxer_97.jpg': 'dog',
#  'boxer_98.jpg': 'dog',
#  'boxer_99.jpg': 'dog',
#  'boxer_9.jpg': 'dog',
#  'British_Shorthair_212.jpg': 'cat',
#  'British_Shorthair_213.jpg': 'cat',
#  'British_Shorthair_218.jpg': 'cat',
#  'British_Shorthair_21.jpg': 'cat',
#  'British_Shorthair_223.jpg': 'cat',
#  'British_Shorthair_22.jpg': 'cat',
#  'British_Shorthair_230.jpg': 'cat',
#  'British_Shorthair_239.jpg': 'cat',
#  'British_Shorthair_241.jpg': 'cat',
#  'British_Shorthair_248.jpg': 'cat',
#  'British_Shorthair_258.jpg': 'cat',
#  'British_Shorthair_25.jpg': 'cat',
#  'British_Shorthair_263.jpg': 'cat',
#  'British_Shorthair_265.jpg': 'cat',
#  'British_Shorthair_266.jpg': 'cat',
#  'British_Shorthair_267.jpg': 'cat',
#  'British_Shorthair_268.jpg': 'cat',
#  'British_Shorthair_269.jpg': 'cat',
#  'British_Shorthair_26.jpg': 'cat',
#  'British_Shorthair_270.jpg': 'cat',
#  'British_Shorthair_271.jpg': 'cat',
#  'British_Shorthair_272.jpg': 'cat',
#  'British_Shorthair_273.jpg': 'cat',
#  'British_Shorthair_274.jpg': 'cat',
#  'British_Shorthair_275.jpg': 'cat',
#  'British_Shorthair_276.jpg': 'cat',
#  'British_Shorthair_277.jpg': 'cat',
#  'British_Shorthair_278.jpg': 'cat',
#  'British_Shorthair_27.jpg': 'cat',
#  'British_Shorthair_28.jpg': 'cat',
#  'British_Shorthair_29.jpg': 'cat',
#  'British_Shorthair_2.jpg': 'cat',
#  'British_Shorthair_30.jpg': 'cat',
#  'British_Shorthair_31.jpg': 'cat',
#  'British_Shorthair_32.jpg': 'cat',
#  'British_Shorthair_33.jpg': 'cat',
#  'British_Shorthair_34.jpg': 'cat',
#  'British_Shorthair_36.jpg': 'cat',
#  'British_Shorthair_37.jpg': 'cat',
#  'British_Shorthair_38.jpg': 'cat',
#  'British_Shorthair_39.jpg': 'cat',
#  'British_Shorthair_3.jpg': 'cat',
#  'British_Shorthair_40.jpg': 'cat',
#  'British_Shorthair_41.jpg': 'cat',
#  'British_Shorthair_42.jpg': 'cat',
#  'British_Shorthair_43.jpg': 'cat',
#  'British_Shorthair_44.jpg': 'cat',
#  'British_Shorthair_45.jpg': 'cat',
#  'British_Shorthair_46.jpg': 'cat',
#  'British_Shorthair_47.jpg': 'cat',
#  'British_Shorthair_48.jpg': 'cat',
#  'British_Shorthair_49.jpg': 'cat',
#  'British_Shorthair_50.jpg': 'cat',
#  'British_Shorthair_51.jpg': 'cat',
#  'British_Shorthair_52.jpg': 'cat',
#  'British_Shorthair_53.jpg': 'cat',
#  'British_Shorthair_54.jpg': 'cat',
#  'British_Shorthair_55.jpg': 'cat',
#  'British_Shorthair_56.jpg': 'cat',
#  'British_Shorthair_57.jpg': 'cat',
#  'British_Shorthair_58.jpg': 'cat',
#  'British_Shorthair_59.jpg': 'cat',
#  'British_Shorthair_60.jpg': 'cat',
#  'British_Shorthair_61.jpg': 'cat',
#  'British_Shorthair_62.jpg': 'cat',
#  'British_Shorthair_63.jpg': 'cat',
#  'British_Shorthair_64.jpg': 'cat',
#  'British_Shorthair_65.jpg': 'cat',
#  'British_Shorthair_66.jpg': 'cat',
#  'British_Shorthair_67.jpg': 'cat',
#  'British_Shorthair_68.jpg': 'cat',
#  'British_Shorthair_6.jpg': 'cat',
#  'British_Shorthair_70.jpg': 'cat',
#  'British_Shorthair_71.jpg': 'cat',
#  'British_Shorthair_72.jpg': 'cat',
#  'British_Shorthair_74.jpg': 'cat',
#  'British_Shorthair_75.jpg': 'cat',
#  'British_Shorthair_77.jpg': 'cat',
#  'British_Shorthair_78.jpg': 'cat',
#  'British_Shorthair_79.jpg': 'cat',
#  'British_Shorthair_82.jpg': 'cat',
#  'British_Shorthair_83.jpg': 'cat',
#  'British_Shorthair_84.jpg': 'cat',
#  'British_Shorthair_85.jpg': 'cat',
#  'British_Shorthair_86.jpg': 'cat',
#  'British_Shorthair_87.jpg': 'cat',
#  'British_Shorthair_88.jpg': 'cat',
#  'British_Shorthair_89.jpg': 'cat',
#  'British_Shorthair_8.jpg': 'cat',
#  'British_Shorthair_90.jpg': 'cat',
#  'British_Shorthair_91.jpg': 'cat',
#  'British_Shorthair_92.jpg': 'cat',
#  'British_Shorthair_93.jpg': 'cat',
#  'British_Shorthair_94.jpg': 'cat',
#  'British_Shorthair_95.jpg': 'cat',
#  'British_Shorthair_96.jpg': 'cat',
#  'British_Shorthair_97.jpg': 'cat',
#  'British_Shorthair_98.jpg': 'cat',
#  'British_Shorthair_99.jpg': 'cat',
#  'British_Shorthair_9.jpg': 'cat',
#  'chihuahua_191.jpg': 'dog',
#  'chihuahua_192.jpg': 'dog',
#  'chihuahua_193.jpg': 'dog',
#  'chihuahua_194.jpg': 'dog',
#  'chihuahua_195.jpg': 'dog',
#  'chihuahua_196.jpg': 'dog',
#  'chihuahua_197.jpg': 'dog',
#  'chihuahua_198.jpg': 'dog',
#  'chihuahua_199.jpg': 'dog',
#  'chihuahua_19.jpg': 'dog',
#  'chihuahua_1.jpg': 'dog',
#  'chihuahua_200.jpg': 'dog',
#  'chihuahua_20.jpg': 'dog',
#  'chihuahua_21.jpg': 'dog',
#  'chihuahua_22.jpg': 'dog',
#  ...}

# %%
#pets.py file have some helper functions which we have used in this project
image_dir = 'data/images/'

def get_random_batch(annot, batch_size=4):
    all_keys = list(annot.keys())
    total_examples = len(all_keys)
    indices = np.random.choice(range(total_examples), batch_size)
    x = np.zeros((batch_size, 128, 128, 3))
    y = np.zeros((batch_size, 1))
    images = []
    
    for i, index in enumerate(indices):
        image = tf.keras.preprocessing.image.load_img(os.path.join(image_dir, all_keys[index]),
                                                     target_size=(128, 128))
        images.append(image)
        arr = tf.keras.preprocessing.image.img_to_array(image)
        arr = tf.keras.applications.mobilenet_v2.preprocess_input(arr)
        arr = np.expand_dims(arr, axis=0)
        x[i] = arr
        y[i] = class_to_index[annot[all_keys[index]]]
    
    return x, y, images

# %%
x, y, images = get_random_batch(train_annot, batch_size=8)
pets.display_examples(x, y, y, images, index_to_class).show()
# Out:
# Displaying first 8 examples..

# %%
#set include_top=False because this model was trained on imagenet dataset and that has like 1000 classes whereas we are trying to do binary classification
mnet = tf.keras.applications.mobilenet_v2.MobileNetV2(include_top=False, input_shape=(128, 128, 3),
                                                     pooling='avg', weights='imagenet')
mnet.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Gowri\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9412608/9406464 [==============================] - 16s 2us/step
# Model: "mobilenetv2_1.00_128"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 129, 129, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 64, 64, 32)   864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 64, 64, 32)   128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 64, 64, 32)   0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 64, 64, 32)   288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 64, 64, 32)   128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 64, 64, 32)   0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 64, 64, 16)   512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 64, 64, 16)   64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 64, 64, 96)   1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 64, 64, 96)   384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 64, 64, 96)   0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 65, 65, 96)   0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 32, 32, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 32, 32, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 32, 32, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 32, 32, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 32, 32, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 32, 32, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 32, 32, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 32, 32, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 32, 32, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 32, 32, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 32, 32, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 32, 32, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 32, 32, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 32, 32, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 32, 32, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 32, 32, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 32, 32, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 33, 33, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 16, 16, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 16, 16, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 16, 16, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 16, 16, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 16, 16, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 16, 16, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 16, 16, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 16, 16, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 16, 16, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 16, 16, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 16, 16, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 16, 16, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 16, 16, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 16, 16, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 16, 16, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 16, 16, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 16, 16, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 16, 16, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 16, 16, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 16, 16, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 16, 16, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 16, 16, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 16, 16, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 16, 16, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 16, 16, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 16, 16, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 17, 17, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 8, 8, 192)    1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 8, 8, 192)    768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 8, 8, 192)    0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 8, 8, 64)     12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 8, 8, 64)     256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 8, 8, 384)    24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 8, 8, 384)    1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 8, 8, 384)    0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 8, 8, 384)    3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 8, 8, 384)    1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 8, 8, 384)    0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 8, 8, 64)     24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 8, 8, 64)     256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 8, 8, 64)     0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 8, 8, 384)    24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 8, 8, 384)    1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 8, 8, 384)    0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 8, 8, 384)    3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 8, 8, 384)    1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 8, 8, 384)    0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 8, 8, 64)     24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 8, 8, 64)     256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 8, 8, 64)     0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 8, 8, 384)    24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 8, 8, 384)    1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 8, 8, 384)    0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 8, 8, 384)    3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 8, 8, 384)    1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 8, 8, 384)    0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 8, 8, 64)     24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 8, 8, 64)     256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 8, 8, 64)     0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 8, 8, 384)    24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 8, 8, 384)    1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 8, 8, 384)    0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 8, 8, 384)    3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 8, 8, 384)    1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 8, 8, 384)    0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 8, 8, 96)     36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 8, 8, 96)     384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 8, 8, 576)    55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 8, 8, 576)    2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 8, 8, 576)    0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 8, 8, 576)    5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 8, 8, 576)    2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 8, 8, 576)    0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 8, 8, 96)     55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 8, 8, 96)     384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 8, 8, 96)     0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 8, 8, 576)    55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 8, 8, 576)    2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 8, 8, 576)    0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 8, 8, 576)    5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 8, 8, 576)    2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 8, 8, 576)    0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 8, 8, 96)     55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 8, 8, 96)     384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 8, 8, 96)     0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 8, 8, 576)    55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 8, 8, 576)    2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 8, 8, 576)    0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 9, 9, 576)    0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 4, 4, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 4, 4, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 4, 4, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 4, 4, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 4, 4, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 4, 4, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 4, 4, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 4, 4, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 4, 4, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 4, 4, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 4, 4, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 4, 4, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 4, 4, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 4, 4, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 4, 4, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 4, 4, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 4, 4, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 4, 4, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 4, 4, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 4, 4, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 4, 4, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 4, 4, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 4, 4, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 4, 4, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 4, 4, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 4, 4, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 4, 4, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 4, 4, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 4, 4, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 4, 4, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 4, 4, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 4, 4, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 4, 4, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 4, 4, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           out_relu[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
def create_model():
    model = tf.keras.models.Sequential([
        mnet,
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.layers[0].trainable = False
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    return model

model = create_model()
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Gowri\Anaconda3\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_128 (Model) (None, 1280)              2257984
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1281
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
def data_generator(batch_size, annot):
    while True:
        x, y, _ = get_random_batch(annot, batch_size)
        yield (x, y)

# %%
batch_size = 32
steps_per_epoch = int(len(list(train_annot.keys()))/batch_size)
validation_steps = int(len(list(test_annot.keys()))/batch_size)

print('Steps per epoch:', steps_per_epoch)
print('Validation steps:', validation_steps)
# Out:
# Steps per epoch: 115
# Validation steps: 114

# %%
# %%time

_ = model.fit_generator(
    data_generator(batch_size, train_annot),
    validation_data=data_generator(batch_size, test_annot),
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    epochs=1
)
# Out:
# 115/115 [==============================] - 190s 2s/step - loss: 0.4340 - acc: 0.8000 - val_loss: 0.1503 - val_acc: 0.9548
# Wall time: 3min 10s

# %%
#red indicates prediction was wrong
x, y, images = get_random_batch(test_annot, batch_size=8)
preds = model.predict(x)
pets.display_examples(x, y, preds, images, index_to_class).show()
# Out:
# Displaying first 8 examples..
